# %% [markdown]
# <a href="https://colab.research.google.com/github/RaghavJ786/Sentiment-Analysis/blob/master/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
#My Twitter API Authentication Variables
consumer_key = 'UgNZ87pe6UyJNGsZng1QuPRIW'
consumer_secret = 'jISRxlRM2O7aG0UvIn6hUrCRCHp9gF41MxLwmPlE3x2TGYLANH'
access_token = '991977861593649152-OgM16N5WjqqNSoe9v507SjP05IuZzVZ'
access_token_secret = 'GelwlEzrzwBenUf0H15bClmC46oB6vH7hyhj0NxGai0ka'

# %%
import tweepy

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)
tweets = api.search('Artificial Intelligence', count=200)

data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])
display(data.head())
print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  Discover the top trends in #IoT for 2019: \nAr...
# 1  RT @anotherhelen: .@grok_, @gdb, @ilyasut, @de...
# 2  RT @cdestou: Can artificial intelligence impro...
# 3  RT @jblefevre60: Can your job be automated by ...
# 4  RT @brevitysoftware: In the years to come, #AI...
# 2019-03-06 07:00:06

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sid= SentimentIntensityAnalyzer()
listy = []
for index, row in data.iterrows():
  ss=sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se=pd.Series(listy)
data['polarity']=se.values
display(data.head(100))
# Out:
#                                                Tweets  \
# 0   Discover the top trends in #IoT for 2019: \nAr...
# 1   RT @anotherhelen: .@grok_, @gdb, @ilyasut, @de...
# 2   RT @cdestou: Can artificial intelligence impro...
# 3   RT @jblefevre60: Can your job be automated by ...
# 4   RT @brevitysoftware: In the years to come, #AI...
# 5   RT @Imagingmeet: Know more at https://t.co/YQ4...
# 6   RT @IBMWatson: 5 key advantages the MIT-IBM Wa...
# 7   Artificial intelligence is slowly making inroa...
# 8   RT @CampusMgmt: "What we wanted to do was buil...
# 9   RT @Sf_Merlo: If #AI contributes to the future...
# 10  RT @ArcadiaLaw: Artificial Intelligence is a p...
# 11          RT @sofeelings00: https://t.co/UKhGUIFWFE
# 12          RT @LovePoint199: https://t.co/QPYSM9V278
# 13  RT @hvgoenka: Artificial intelligence(AI) is t...
# 14  “ Is #AI like @IBMWatson poised to replace doc...
# 15  Artificial intelligence - Organisation for Eco...
# ...
